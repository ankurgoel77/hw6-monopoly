# %% [markdown]
# # San Francisco Housing Cost Analysis
#
# In this assignment, you will perform fundamental analysis for the San Francisco housing market to allow potential real estate investors to choose rental investment properties.

# %%
# imports

import numpy as np
import pandas as pd
import os
from pathlib import Path
from dotenv import load_dotenv
import matplotlib.pyplot as plt
import hvplot.pandas
import panel as pn
pn.extension('plotly')
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %%
# Read the Mapbox API key
load_dotenv()
map_box_api = os.getenv("MAPBOX_API_KEY")
print(type(map_box_api))
# Out:
# <class 'str'>

# %% [markdown]
# ## Load Data

# %%
# Read the census data into a Pandas DataFrame
file_path = Path("Data/sfo_neighborhoods_census_data.csv")
sfo_data = pd.read_csv(file_path, index_col="year")
sfo_data.head()
# Out:
#           neighborhood  sale_price_sqr_foot  housing_units  gross_rent
# year
# 2010      Alamo Square           291.182945         372560        1239
# 2010        Anza Vista           267.932583         372560        1239
# 2010           Bayview           170.098665         372560        1239
# 2010  Buena Vista Park           347.394919         372560        1239
# 2010  Central Richmond           319.027623         372560        1239

# %% [markdown]
# - - -

# %% [markdown]
# ## Housing Units Per Year
#
# In this section, you will calculate the number of housing units per year and visualize the results as a bar chart using the Pandas plot function.
#
# **Hint:** Use the Pandas `groupby` function.
#
# **Optional challenge:** Use the min, max, and std to scale the y limits of the chart.

# %%
# Calculate the mean number of housing units per year (hint: use groupby) 
mean_housing_year = sfo_data["housing_units"].groupby("year").mean()
mean_housing_year.head(10)
# Out:
# year
# 2010    372560
# 2011    374507
# 2012    376454
# 2013    378401
# 2014    380348
# 2015    382295
# 2016    384242
# Name: housing_units, dtype: int64

# %%
# Save the dataframe as a csv file
file_path = Path("Data/sfo_mean_housing_units_year.csv")
mean_housing_df = pd.DataFrame(mean_housing_year)
mean_housing_df.columns = ['Mean Housing per Year']
mean_housing_df.to_csv(file_path, header = True)

# %%
# Use the Pandas plot function to plot the average housing units per year.
# Note: You will need to manually adjust the y limit of the chart using the min and max values from above.
mean_housing_df.plot.bar(title="San Francisco Mean Housing per Year", ylim=(370000,390000))

# Optional Challenge: Use the min, max, and std to scale the y limits of the chart
housing_min = mean_housing_df['Mean Housing per Year'].min()
housing_max = mean_housing_df['Mean Housing per Year'].max()
housing_std = mean_housing_df['Mean Housing per Year'].std()
mean_housing_df.plot.bar(title="Challenge: San Francisco Mean Housing per Year", ylim=(housing_min-housing_std,housing_max+housing_std))

# %% [markdown]
# - - -

# %% [markdown]
# ## Average Housing Costs in San Francisco Per Year
#
# In this section, you will calculate the average monthly rent and the average price per square foot for each year. An investor may wish to better understand the sales price of the rental property over time. For example, a customer will want to know if they should expect an increase or decrease in the property value over time so they can determine how long to hold the rental property.  Plot the results as two line charts.
#
# **Optional challenge:** Plot each line chart in a different color.

# %%
# Calculate the average sale price per square foot and average gross rent
averages_by_year = sfo_data[['sale_price_sqr_foot', 'gross_rent']].groupby("year").mean()
averages_by_year.head()
# Out:
#       sale_price_sqr_foot  gross_rent
# year
# 2010           369.344353        1239
# 2011           341.903429        1530
# 2012           399.389968        2324
# 2013           483.600304        2971
# 2014           556.277273        3528

# %%
# Create two line charts, one to plot the average sale price per square foot and another for average montly rent

# Line chart for average sale price per square foot
plt.figure()
a = averages_by_year['sale_price_sqr_foot'].plot.line(title="Average Price per SqFt by Year",color="Blue")


# Line chart for average montly rent
plt.figure()
b =averages_by_year['gross_rent'].plot.line(title="Average Gross Rent Per Year",color="Orange")

# %% [markdown]
# - - -

# %% [markdown]
# ## Average Prices by Neighborhood
#
# In this section, you will use hvplot to create two interactive visulizations of average prices with a dropdown selector for the neighborhood. The first visualization will be a line plot showing the trend of average price per square foot over time for each neighborhood.  The second will be a line plot showing the trend of average montly rent over time for each neighborhood.
#
# **Hint:** It will be easier to create a new DataFrame from grouping the data and calculating the mean prices for each year and neighborhood

# %%
# Group by year and neighborhood and then create a new dataframe of the mean values
avg_df = sfo_data.groupby(["year",'neighborhood']).mean().reset_index()
avg_df.head(10)
# Out:
#    year      neighborhood  sale_price_sqr_foot  housing_units  gross_rent
# 0  2010      Alamo Square           291.182945         372560        1239
# 1  2010        Anza Vista           267.932583         372560        1239
# 2  2010           Bayview           170.098665         372560        1239
# 3  2010  Buena Vista Park           347.394919         372560        1239
# 4  2010  Central Richmond           319.027623         372560        1239
# 5  2010    Central Sunset           418.172493         372560        1239
# 6  2010    Corona Heights           369.359338         372560        1239
# 7  2010        Cow Hollow           569.379968         372560        1239
# 8  2010     Croker Amazon           165.645730         372560        1239
# 9  2010   Diamond Heights           456.930822         372560        1239

# %%
# Use hvplot to create an interactive line chart of the average price per sq ft.
# The plot should have a dropdown selector for the neighborhood
avg_df.hvplot.line(x='year',y='sale_price_sqr_foot', groupby="neighborhood").opts(title="Average Sales per Sq Ft per Year by Neighborhood")
# Out:
# :DynamicMap   [neighborhood]
#    :Curve   [year]   (sale_price_sqr_foot)

# %%
# Use hvplot to create an interactive line chart of the average monthly rent.
# The plot should have a dropdown selector for the neighborhood
avg_df.hvplot.line(x='year',y='gross_rent', groupby="neighborhood").opts(title="Average Rent per Year by Neighborhood")
# Out:
# :DynamicMap   [neighborhood]
#    :Curve   [year]   (gross_rent)

# %% [markdown]
# ## The Top 10 Most Expensive Neighborhoods
#
# In this section, you will need to calculate the mean sale price per square foot for each neighborhood and then sort the values to obtain the top 10 most expensive neighborhoods on average. Plot the results as a bar chart.

# %%
# Getting the data from the top 10 expensive neighborhoods to own
top10 = sfo_data.groupby('neighborhood').mean().nlargest(10,'sale_price_sqr_foot').reset_index()
top10
# Out:
#             neighborhood  sale_price_sqr_foot  housing_units   gross_rent
# 0  Union Square District           903.993258      377427.50  2555.166667
# 1         Merced Heights           788.844818      380348.00  3414.000000
# 2          Miraloma Park           779.810842      375967.25  2155.250000
# 3        Pacific Heights           689.555817      378401.00  2817.285714
# 4          Westwood Park           687.087575      382295.00  3959.000000
# 5         Telegraph Hill           676.506578      378401.00  2817.285714
# 6       Presidio Heights           675.350212      378401.00  2817.285714
# 7             Cow Hollow           665.964042      378401.00  2817.285714
# 8           Potrero Hill           662.013613      378401.00  2817.285714
# 9            South Beach           650.124479      375805.00  2099.000000

# %%
# Plotting the data from the top 10 expensive neighborhoods
top10.hvplot.bar(title="Top 10 Most Expensive Neighborhoods to own per square foot", x='neighborhood', y="sale_price_sqr_foot", rot=45)
# Out:
# :Bars   [neighborhood]   (sale_price_sqr_foot)

# %% [markdown]
# - - -

# %% [markdown]
# ## Comparing cost to purchase versus rental income
#
# In this section, you will use `hvplot` to create an interactive visualization with a dropdown selector for the neighborhood. This visualization will feature a side-by-side comparison of average price per square foot versus average montly rent by year.
#
# **Hint:** Use the `hvplot` parameter, `groupby`, to create a dropdown selector for the neighborhood.

# %%
# Fetch the previously generated DataFrame that was grouped by year and neighborhood
avg_df.head(10)
# Out:
#    year      neighborhood  sale_price_sqr_foot  housing_units  gross_rent
# 0  2010      Alamo Square           291.182945         372560        1239
# 1  2010        Anza Vista           267.932583         372560        1239
# 2  2010           Bayview           170.098665         372560        1239
# 3  2010  Buena Vista Park           347.394919         372560        1239
# 4  2010  Central Richmond           319.027623         372560        1239
# 5  2010    Central Sunset           418.172493         372560        1239
# 6  2010    Corona Heights           369.359338         372560        1239
# 7  2010        Cow Hollow           569.379968         372560        1239
# 8  2010     Croker Amazon           165.645730         372560        1239
# 9  2010   Diamond Heights           456.930822         372560        1239

# %%
# Plotting the data from the top 10 expensive neighborhoods
sales_plot=avg_df.hvplot.line(x='year',y='sale_price_sqr_foot', groupby="neighborhood").opts(title="Average Sales per Sq Ft per Year by Neighborhood") 
rental_plot = avg_df.hvplot.line(x='year',y='gross_rent', groupby="neighborhood").opts(title="Average Rent per Year by Neighborhood")
sales_plot + rental_plot
# Out:
# :Layout
#    .DynamicMap.I  :DynamicMap   [neighborhood]
#       :Curve   [year]   (sale_price_sqr_foot)
#    .DynamicMap.II :DynamicMap   [neighborhood]
#       :Curve   [year]   (gross_rent)

# %% [markdown]
# - - -

# %% [markdown]
# ## Neighborhood Map
#
# In this section, you will read in neighborhoods location data and build an interactive map with the average house value per neighborhood. Use a `scatter_mapbox` from Plotly express to create the visualization. Remember, you will need your Mapbox API key for this.

# %% [markdown]
# ### Load Location Data

# %%
# Load neighborhoods coordinates data
file_path = Path("Data/neighborhoods_coordinates.csv")
sfo_coords = pd.read_csv(file_path)
sfo_coords.head()
# Out:
#       Neighborhood        Lat         Lon
# 0     Alamo Square  37.791012 -122.402100
# 1       Anza Vista  37.779598 -122.443451
# 2          Bayview  37.734670 -122.401060
# 3  Bayview Heights  37.728740 -122.410980
# 4   Bernal Heights  37.728630 -122.443050

# %% [markdown]
# ### Data Preparation
#
# You will need to join the location data with the mean values per neighborhood.
#
# 1. Calculate the mean values for each neighborhood.
#
# 2. Join the average values with the neighborhood locations.

# %%
# Calculate the mean values for each neighborhood
neighborhood_means = sfo_data.groupby('neighborhood').mean().reset_index()
neighborhood_means.head()
# Out:
#       neighborhood  sale_price_sqr_foot  housing_units   gross_rent
# 0     Alamo Square           366.020712       378401.0  2817.285714
# 1       Anza Vista           373.382198       379050.0  3031.833333
# 2          Bayview           204.588623       376454.0  2318.400000
# 3  Bayview Heights           590.792839       382295.0  3739.000000
# 4  Bernal Heights            576.746488       379374.5  3080.333333

# %%
# Join the average values with the neighborhood locations
sfo_coords_avg_values = pd.concat([sfo_coords, neighborhood_means], axis=1, join="inner").drop("neighborhood",axis=1)
sfo_coords_avg_values
# Out:
#                      Neighborhood        Lat         Lon  sale_price_sqr_foot  \
# 0                    Alamo Square  37.791012 -122.402100           366.020712
# 1                      Anza Vista  37.779598 -122.443451           373.382198
# 2                         Bayview  37.734670 -122.401060           204.588623
# 3                 Bayview Heights  37.728740 -122.410980           590.792839
# 4                  Bernal Heights  37.728630 -122.443050           576.746488
# 5                Buena Vista Park  37.768160 -122.439330           452.680591
# 6                Central Richmond  37.777890 -122.445170           394.422399
# 7                  Central Sunset  37.749610 -122.489990           423.687928
# 8               Clarendon Heights  37.753310 -122.447030           487.244886
# 9                  Corona Heights  37.785530 -122.456000           587.539067
# 10                     Cow Hollow  37.792980 -122.435790           665.964042
# 11                  Croker Amazon  37.722800 -122.438690           303.004184
# 12                Diamond Heights  37.728630 -122.443050           434.991739
# 13                       Downtown  37.791010 -122.402100           391.434378
# 14                Duboce Triangle  37.769640 -122.426110           502.599156
# 15  Eureka Valley/Dolores Heights  37.755540 -122.437790           642.248671
# 16                      Excelsior  37.728740 -122.410980           388.765927
# 17       Financial District North  37.791010 -122.402100           391.362533
# 18       Financial District South  37.791010 -122.402100           455.836212
# 19                  Forest Knolls  37.757060 -122.455090           321.840837
# 20                      Glen Park  37.728630 -122.443050           623.826178
# 21            Golden Gate Heights  37.757912 -122.464020           639.393557
# 22                 Haight Ashbury  37.765250 -122.435960           449.544762
# 23                   Hayes Valley  37.765250 -122.435960           355.932828
# 24                  Hunters Point  37.725510 -122.371780           170.624920
# 25                      Ingleside  37.721161 -122.487068           367.895144
# 26              Ingleside Heights  37.721160 -122.487070           384.797928
# 27                  Inner Mission  37.754160 -122.419470           397.673715
# 28                 Inner Parkside  37.749610 -122.489990           519.385604
# 29                 Inner Richmond  37.769112 -122.483566           378.594314
# ..                            ...        ...         ...                  ...
# 43                     Noe Valley  37.753310 -122.447030           542.442913
# 44                    North Beach  37.800550 -122.404330           411.646876
# 45               North Waterfront  37.800550 -122.404330           498.269755
# 46                      Oceanview  37.719930 -122.465950           330.097385
# 47                  Outer Mission  37.722800 -122.438690           242.370952
# 48                 Outer Parkside  37.751700 -122.446000           485.027013
# 49                 Outer Richmond  37.769110 -122.483570           473.900773
# 50                   Outer Sunset  37.749610 -122.489990           394.219032
# 51                Pacific Heights  37.792980 -122.435790           689.555817
# 52                     Park North  37.728380 -122.478510           373.732856
# 53                       Parkside  37.749610 -122.489990           336.172661
# 54      Parnassus/Ashbury Heights  37.763550 -122.457650           632.740454
# 55                        Portola  37.734670 -122.401060           327.113925
# 56                   Potrero Hill  37.731960 -122.383240           662.013613
# 57               Presidio Heights  37.785530 -122.456000           675.350212
# 58                   Russian Hill  37.792980 -122.435790           608.983217
# 59                 Silver Terrace  37.734670 -122.401060           170.292549
# 60                    South Beach  37.783230 -122.400650           650.124479
# 61                South of Market  37.791010 -122.402100           570.271427
# 62                      Sunnyside  37.734150 -122.457000           528.318332
# 63                 Telegraph Hill  37.800550 -122.404330           676.506578
# 64                     Twin Peaks  37.753311 -122.447029           469.398626
# 65          Union Square District  37.791010 -122.402100           903.993258
# 66         Van Ness/ Civic Center  37.779510 -122.420220           404.150180
# 67              Visitacion Valley  37.728740 -122.410980           301.466180
# 68                    West Portal  37.740260 -122.463880           498.488485
# 69               Western Addition  37.792980 -122.435790           307.562201
# 70             Westwood Highlands  37.734700 -122.456854           533.703935
# 71                  Westwood Park  37.734150 -122.457000           687.087575
# 72                    Yerba Buena  37.792980 -122.396360           576.709848
#
#     housing_units   gross_rent
# 0       378401.00  2817.285714
# 1       379050.00  3031.833333
# 2       376454.00  2318.400000
# 3       382295.00  3739.000000
# 4       379374.50  3080.333333
# 5       378076.50  2698.833333
# 6       378401.00  2817.285714
# 7       378401.00  2817.285714
# 8       376454.00  2250.500000
# 9       377232.80  2472.000000
# 10      378401.00  2817.285714
# 11      378076.50  2698.833333
# 12      375480.50  2016.000000
# 13      378401.00  2817.285714
# 14      378401.00  2780.250000
# 15      378401.00  2817.285714
# 16      379050.00  3031.833333
# 17      378401.00  2817.285714
# 18      377232.80  2472.000000
# 19      374507.00  1781.500000
# 20      378725.50  2899.500000
# 21      377622.20  2601.400000
# 22      378401.00  2817.285714
# 23      378401.00  2817.285714
# 24      377427.50  2489.000000
# 25      377427.50  2509.000000
# 26      379374.50  2960.000000
# 27      378401.00  2817.285714
# 28      379861.25  3224.000000
# 29      378401.00  2817.285714
# ..            ...          ...
# 43      378401.00  2817.285714
# 44      379179.80  2990.800000
# 45      378401.00  2818.400000
# 46      377103.00  2434.000000
# 47      379374.50  2995.750000
# 48      378401.00  2817.285714
# 49      378401.00  2817.285714
# 50      378401.00  2817.285714
# 51      378401.00  2817.285714
# 52      378401.00  2817.285714
# 53      377427.50  2555.166667
# 54      378401.00  2817.285714
# 55      376454.00  2318.400000
# 56      378401.00  2817.285714
# 57      378401.00  2817.285714
# 58      378401.00  2817.285714
# 59      380348.00  3528.000000
# 60      375805.00  2099.000000
# 61      378401.00  2817.285714
# 62      378725.50  2899.500000
# 63      378401.00  2817.285714
# 64      378401.00  2817.285714
# 65      377427.50  2555.166667
# 66      378401.00  2817.285714
# 67      381321.50  3657.000000
# 68      376940.75  2515.500000
# 69      377427.50  2555.166667
# 70      376454.00  2250.500000
# 71      382295.00  3959.000000
# 72      377427.50  2555.166667
#
# [73 rows x 6 columns]

# %% [markdown]
# ### Mapbox Visualization
#
# Plot the average values per neighborhood using a Plotly express `scatter_mapbox` visualization.

# %%
# Set the mapbox access token
px.set_mapbox_access_token(map_box_api)

# Create a scatter mapbox to analyze neighborhood info
map_plot = px.scatter_mapbox(
    sfo_coords_avg_values,
    lat="Lat",
    lon="Lon",
    size="sale_price_sqr_foot",
    color="gross_rent",
    zoom=10,
    hover_name='Neighborhood'
)
map_plot.show()

# %% [markdown]
# - - -

# %% [markdown]
# ## Cost Analysis - Optional Challenge
#
# In this section, you will use Plotly express to create visualizations that investors can use to interactively filter and explore various factors related to the house value of the San Francisco's neighborhoods.
#
# ### Create a DataFrame showing the most expensive neighborhoods in San Francisco by year

# %%
# Fetch the data from all expensive neighborhoods per year.
df_expensive_neighborhoods_per_year = df_costs[df_costs["neighborhood"].isin(df_expensive_neighborhoods["neighborhood"])]
df_expensive_neighborhoods_per_year.head()
# Out:
#     year      neighborhood  sale_price_sqr_foot  housing_units  gross_rent
# 7   2010        Cow Hollow           569.379968         372560        1239
# 31  2010     Miraloma Park           680.608729         372560        1239
# 41  2010   Pacific Heights           496.516014         372560        1239
# 46  2010      Potrero Hill           491.450004         372560        1239
# 47  2010  Presidio Heights           549.417931         372560        1239

# %% [markdown]
# ### Create a parallel coordinates plot and parallel categories plot of most expensive neighborhoods in San Francisco per year

# %%
# Parallel Categories Plot
# YOUR CODE HERE!

# %%
# Parallel Coordinates Plot
# YOUR CODE HERE!

# %% [markdown]
# ### Create a sunburst chart to conduct a costs analysis of most expensive neighborhoods in San Francisco per year

# %%
# Sunburst Plot
# YOUR CODE HERE!
